# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Data Visualization and Analysis\n",
    "\n",
    "This notebook provides visualizations and analysis of the model's performance."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "source": [
    "import sys\n",
    "sys.path.append('..')\n",
    "\n",
    "import pandas as pd\n",
    "import numpy as np\n",
    "import matplotlib.pyplot as plt\n",
    "import seaborn as sns\n",
    "from src.utils.metrics import MetricsTracker"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 1. Load Training Metrics"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "source": [
    "# Load metrics\n",
    "with open('../results/training_metrics.json', 'r') as f:\n",
    "    metrics = json.load(f)\n",
    "\n",
    "# Create plots\n",
    "plt.figure(figsize=(12, 6))\n",
    "plt.plot(metrics['loss'], label='Loss')\n",
    "plt.plot(metrics['accuracy'], label='Accuracy')\n",
    "plt.title('Training Metrics')\n",
    "plt.xlabel('Round')\n",
    "plt.ylabel('Value')\n",
    "plt.legend()\n",
    "plt.grid(True)\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 2. Privacy Analysis"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "source": [
    "# Plot privacy budget consumption\n",
    "plt.figure(figsize=(10, 6))\n",
    "plt.plot(metrics['privacy_budget'], 'g-')\n",
    "plt.title('Privacy Budget Consumption')\n",
    "plt.xlabel('Round')\n",
    "plt.ylabel('Epsilon')\n",
    "plt.grid(True)\n",
    "plt.show()"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python"
  }
 }
}
